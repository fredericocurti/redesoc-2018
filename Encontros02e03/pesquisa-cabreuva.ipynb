# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
pd.set_option('display.max_columns',50 )
pd.set_option('display.max_rows', 250)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

d = pd.read_csv("./cabreuva_limpa.csv", encoding='ISO-8859-1')

# %%
d
# Out:
#       Unnamed: 0                    ESCOLA  \
# 0              1   EE ANA MESQUITA LAURINI
# 1              2   EE ANA MESQUITA LAURINI
# 2              3   EE ANA MESQUITA LAURINI
# 3              4   EE ANA MESQUITA LAURINI
# 4              5   EE ANA MESQUITA LAURINI
# 5              6   EE ANA MESQUITA LAURINI
# 6              7   EE ANA MESQUITA LAURINI
# 7              8   EE ANA MESQUITA LAURINI
# 8              9   EE ANA MESQUITA LAURINI
# 9             10   EE ANA MESQUITA LAURINI
# 10            11   EE ANA MESQUITA LAURINI
# 11            12   EE ANA MESQUITA LAURINI
# 12            13   EE ANA MESQUITA LAURINI
# 13            14   EE ANA MESQUITA LAURINI
# 14            15   EE ANA MESQUITA LAURINI
# 15            16   EE ANA MESQUITA LAURINI
# 16            17   EE ANA MESQUITA LAURINI
# 17            18   EE ANA MESQUITA LAURINI
# 18            19   EE ANA MESQUITA LAURINI
# 19            20   EE ANA MESQUITA LAURINI
# 20            21   EE ANA MESQUITA LAURINI
# ...

# %% [markdown]
# <br>
# <h1> Relação conforto com filho homossexual / religião </h1>

# %%
ct1 = pd.crosstab(d["religiao"],d["FILHALÉSBICA"])
ct1.plot(kind='bar', figsize=(16,6))

# %% [markdown]
# <h1> Religião </h1>

# %%
a = d["RELIGIÃO"]
pd.value_counts(a).plot(kind='pie', figsize=(10,10))

# %%
a = d["RELIGIÃO"] == "Sou ateu" and d["RELIGIÃO"] == "Eu não tenho religião"
a.value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-afd221a3dd97> in <module>()
# ----> 1 a = d["RELIGIÃO"] == "Sou ateu" and d["RELIGIÃO"] == "Eu não tenho religião"
#       2 a.value_counts().plot(kind='pie', figsize=(6,6))
#
# ~/.virtualenvs/jupyter/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
d.RELIGIÃO == "Eu não tenho religião" or d.RELIGIÃO == "Eu sou ateu"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-293f1555dc85> in <module>()
# ----> 1 d.RELIGIÃO == "Eu não tenho religião" or d.RELIGIÃO == "Eu sou ateu"
#
# ~/.virtualenvs/jupyter/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
